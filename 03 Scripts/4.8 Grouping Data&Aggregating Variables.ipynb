# %% [markdown]
# ## 1. Import Libraries

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Import Data

# %%
# Defining path
path = r'C:\Users\Dudab\Oct 2023 - Instacart Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_updated.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# 1         Soda        77              7     9.0   both  Regularly busy
# 2         Soda        77              7     9.0   both  Regularly busy
# 3         Soda        77              7     9.0   both      Least busy
# 4         Soda        77              7     9.0   both      Least busy
#
#       busiest_days busiest_period_of_day
# 0   Regularly busy        Average orders
# 1  Least busy days        Average orders
# 2  Least busy days           Most orders
# 3  Least busy days        Average orders
# 4  Least busy days           Most orders

# %%
# Checking for null values.
ords_prods_merge.isnull().sum()
# Out:
# order_id                        0
# user_id                         0
# order_number                    0
# orders_day_of_week              0
# order_hour_of_day               0
# days_since_prior_order    2076096
# product_id                      0
# add_to_cart_order               0
# reordered                       0
# product_name                    0
# aisle_id                        0
# department_id                   0
# prices                          0
# _merge                          0
# busiest_day                     0
# busiest_days                    0
# busiest_period_of_day           0
# dtype: int64

# %% [markdown]
# # 3. Exercise

# %%
# Creating subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# 1         Soda        77              7     9.0   both  Regularly busy
# 2         Soda        77              7     9.0   both  Regularly busy
# 3         Soda        77              7     9.0   both      Least busy
# 4         Soda        77              7     9.0   both      Least busy
#
#       busiest_days busiest_period_of_day
# 0   Regularly busy        Average orders
# 1  Least busy days        Average orders
# 2  Least busy days           Most orders
# 3  Least busy days        Average orders
# 4  Least busy days           Most orders

# %% [markdown]
# ## Grouping Data

# %%
df.groupby('product_name')

# %% [markdown]
# #### step 1 to group data usefully

# %% [markdown]
# ## Aggregate Data with agg()

# %%
# Calculate mean of order_number column grouped by department_id column
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Using mean function to achieve above results
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Multiple aggregations
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ## Aggregating Data with transform()

# %%
# Creating max_order column to show customers based on their max order_number
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\Dudab\AppData\Local\Temp\ipykernel_10936\1838814253.py:2: FutureWarning: The provided callable <function amax at 0x000001C8629A1A80> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# 1         Soda        77              7     9.0   both  Regularly busy
# 2         Soda        77              7     9.0   both  Regularly busy
# 3         Soda        77              7     9.0   both      Least busy
# 4         Soda        77              7     9.0   both      Least busy
#
#       busiest_days busiest_period_of_day  max_order
# 0   Regularly busy        Average orders         10
# 1  Least busy days        Average orders         10
# 2  Least busy days           Most orders         10
# 3  Least busy days        Average orders         10
# 4  Least busy days           Most orders         10

# %% [markdown]
# ## Deriving Columns with loc()

# %%
# Applying loyalty flag to max_order column using loc function
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\Users\Dudab\AppData\Local\Temp\ipykernel_10936\1657514324.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Loyal customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0         Soda        77              7     9.0   both  Regularly busy
# 1         Soda        77              7     9.0   both  Regularly busy
# 2         Soda        77              7     9.0   both  Regularly busy
# 3         Soda        77              7     9.0   both      Least busy
# 4         Soda        77              7     9.0   both      Least busy
#
#       busiest_days busiest_period_of_day  max_order  loyalty_flag
# 0   Regularly busy        Average orders         10  New customer
# 1  Least busy days        Average orders         10  New customer
# 2  Least busy days           Most orders         10  New customer
# 3  Least busy days        Average orders         10  New customer
# 4  Least busy days           Most orders         10  New customer

# %% [markdown]
# # 4. Task

# %%
#2 find the aggregated mean of the “order_number” column grouped by “department_id” column for the entire dataframe
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# #3 he majority of methods closely align with the findings in the subset, with only specific ones, such as department_id "10" and "21," exhibiting a deviation of more than 1 or 2

# %%
#4 Use the loyalty flag and check the basic statistics of the product prices for each loyalty category
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# Loyal customers seem to prefer purchasing less costly items, potentially leading to increased buying frequency, which, in turn, could result in them being categorized as loyal customers.

# %%
#6 Create a spending flag for each user based on the average price across all their orders

# Creating mean_spend column to show customers based on their mean prices across products
ords_prods_merge['mean_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\Dudab\AppData\Local\Temp\ipykernel_10936\1917204150.py:4: FutureWarning: The provided callable <function mean at 0x000001C8629A27A0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['mean_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
#
#    product_name  aisle_id  department_id  prices _merge     busiest_day  \
# 0          Soda        77              7     9.0   both  Regularly busy
# 1          Soda        77              7     9.0   both  Regularly busy
# 2          Soda        77              7     9.0   both  Regularly busy
# 3          Soda        77              7     9.0   both      Least busy
# 4          Soda        77              7     9.0   both      Least busy
# 5          Soda        77              7     9.0   both  Regularly busy
# 6          Soda        77              7     9.0   both  Regularly busy
# 7          Soda        77              7     9.0   both  Regularly busy
# 8          Soda        77              7     9.0   both  Regularly busy
# 9          Soda        77              7     9.0   both      Least busy
# 10         Soda        77              7     9.0   both  Regularly busy
# 11         Soda        77              7     9.0   both  Regularly busy
# 12         Soda        77              7     9.0   both  Regularly busy
# 13         Soda        77              7     9.0   both  Regularly busy
# 14         Soda        77              7     9.0   both  Regularly busy
#
#        busiest_days busiest_period_of_day  max_order      loyalty_flag  \
# 0    Regularly busy        Average orders         10      New customer
# 1   Least busy days        Average orders         10      New customer
# 2   Least busy days           Most orders         10      New customer
# 3   Least busy days        Average orders         10      New customer
# 4   Least busy days           Most orders         10      New customer
# 5    Regularly busy        Average orders         10      New customer
# 6      Busiest days           Most orders         10      New customer
# 7      Busiest days           Most orders         10      New customer
# 8      Busiest days           Most orders         10      New customer
# 9   Least busy days        Average orders         10      New customer
# 10     Busiest days           Most orders         22  Regular customer
# 11   Regularly busy           Most orders         22  Regular customer
# 12   Regularly busy           Most orders         22  Regular customer
# 13     Busiest days           Most orders         22  Regular customer
# 14     Busiest days           Most orders         22  Regular customer
#
#     mean_spend
# 0     6.367797
# 1     6.367797
# 2     6.367797
# 3     6.367797
# 4     6.367797
# 5     6.367797
# 6     6.367797
# 7     6.367797
# 8     6.367797
# 9     6.367797
# 10    3.980556
# 11    3.980556
# 12    3.980556
# 13    3.980556
# 14    3.980556

# %%
# Creating column with spender flag based on criteria
ords_prods_merge.loc[ords_prods_merge['mean_spend'] < 10, 'spender_flag'] = 'Low spender'
# Out:
# C:\Users\Dudab\AppData\Local\Temp\ipykernel_10936\2624053869.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low spender' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['mean_spend'] < 10, 'spender_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_spend'] >= 10, 'spender_flag'] = 'High spender'

# %%
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  department_id  prices  _merge     busiest_day  \
# 0         Soda  ...              7     9.0    both  Regularly busy
# 1         Soda  ...              7     9.0    both  Regularly busy
# 2         Soda  ...              7     9.0    both  Regularly busy
# 3         Soda  ...              7     9.0    both      Least busy
# 4         Soda  ...              7     9.0    both      Least busy
#
#       busiest_days busiest_period_of_day max_order  loyalty_flag mean_spend  \
# 0   Regularly busy        Average orders        10  New customer   6.367797
# 1  Least busy days        Average orders        10  New customer   6.367797
# 2  Least busy days           Most orders        10  New customer   6.367797
# 3  Least busy days        Average orders        10  New customer   6.367797
# 4  Least busy days           Most orders        10  New customer   6.367797
#
#    spender_flag
# 0   Low spender
# 1   Low spender
# 2   Low spender
# 3   Low spender
# 4   Low spender
#
# [5 rows x 21 columns]

# %%
#7 Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column

# Creating median_order_frequency column to show customers based on their median days_since_prior_order
ords_prods_merge['median_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\Dudab\AppData\Local\Temp\ipykernel_10936\194415693.py:4: FutureWarning: The provided callable <function median at 0x000001C862AE3740> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['median_order_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# 11   1870022       15            17                   2                 16
# 12   1911383       15            18                   2                 11
# 13   2715276       15            21                   1                  9
# 14    487368       15            22                   1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
#
#    product_name  ...  prices  _merge     busiest_day     busiest_days  \
# 0          Soda  ...     9.0    both  Regularly busy   Regularly busy
# 1          Soda  ...     9.0    both  Regularly busy  Least busy days
# 2          Soda  ...     9.0    both  Regularly busy  Least busy days
# 3          Soda  ...     9.0    both      Least busy  Least busy days
# 4          Soda  ...     9.0    both      Least busy  Least busy days
# 5          Soda  ...     9.0    both  Regularly busy   Regularly busy
# 6          Soda  ...     9.0    both  Regularly busy     Busiest days
# 7          Soda  ...     9.0    both  Regularly busy     Busiest days
# 8          Soda  ...     9.0    both  Regularly busy     Busiest days
# 9          Soda  ...     9.0    both      Least busy  Least busy days
# 10         Soda  ...     9.0    both  Regularly busy     Busiest days
# 11         Soda  ...     9.0    both  Regularly busy   Regularly busy
# 12         Soda  ...     9.0    both  Regularly busy   Regularly busy
# 13         Soda  ...     9.0    both  Regularly busy     Busiest days
# 14         Soda  ...     9.0    both  Regularly busy     Busiest days
#
#    busiest_period_of_day max_order      loyalty_flag  mean_spend spender_flag  \
# 0         Average orders        10      New customer    6.367797  Low spender
# 1         Average orders        10      New customer    6.367797  Low spender
# 2            Most orders        10      New customer    6.367797  Low spender
# 3         Average orders        10      New customer    6.367797  Low spender
# 4            Most orders        10      New customer    6.367797  Low spender
# 5         Average orders        10      New customer    6.367797  Low spender
# 6            Most orders        10      New customer    6.367797  Low spender
# 7            Most orders        10      New customer    6.367797  Low spender
# 8            Most orders        10      New customer    6.367797  Low spender
# 9         Average orders        10      New customer    6.367797  Low spender
# 10           Most orders        22  Regular customer    3.980556  Low spender
# 11           Most orders        22  Regular customer    3.980556  Low spender
# 12           Most orders        22  Regular customer    3.980556  Low spender
# 13           Most orders        22  Regular customer    3.980556  Low spender
# 14           Most orders        22  Regular customer    3.980556  Low spender
#
#     median_order_frequency
# 0                     20.5
# 1                     20.5
# 2                     20.5
# 3                     20.5
# 4                     20.5
# 5                     20.5
# 6                     20.5
# 7                     20.5
# 8                     20.5
# 9                     20.5
# 10                    10.0
# 11                    10.0
# 12                    10.0
# 13                    10.0
# 14                    10.0
#
# [15 rows x 22 columns]

# %%
ords_prods_merge['median_order_frequency'].isnull().sum()
# Out:
# 5

# %%
# Creating column with frequency flag based on criteria
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
# Out:
# C:\Users\Dudab\AppData\Local\Temp\ipykernel_10936\1132620678.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Non-frequent customer' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_order_frequency'] <= 20) & (ords_prods_merge['median_order_frequency'] > 10), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_order_frequency'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge     busiest_day     busiest_days  \
# 0         Soda  ...    both  Regularly busy   Regularly busy
# 1         Soda  ...    both  Regularly busy  Least busy days
# 2         Soda  ...    both  Regularly busy  Least busy days
# 3         Soda  ...    both      Least busy  Least busy days
# 4         Soda  ...    both      Least busy  Least busy days
#
#   busiest_period_of_day max_order  loyalty_flag mean_spend  spender_flag  \
# 0        Average orders        10  New customer   6.367797   Low spender
# 1        Average orders        10  New customer   6.367797   Low spender
# 2           Most orders        10  New customer   6.367797   Low spender
# 3        Average orders        10  New customer   6.367797   Low spender
# 4           Most orders        10  New customer   6.367797   Low spender
#
#   median_order_frequency   order_frequency_flag
# 0                   20.5  Non-frequent customer
# 1                   20.5  Non-frequent customer
# 2                   20.5  Non-frequent customer
# 3                   20.5  Non-frequent customer
# 4                   20.5  Non-frequent customer
#
# [5 rows x 23 columns]

# %%
# Checking about the null values in the new columns
df_nan = ords_prods_merge[ords_prods_merge['order_frequency_flag'].isnull() == True]

# %%
df_nan
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 13645692    895835   159838             1                   0
# 17251990    895835   159838             1                   0
# 17622767    895835   159838             1                   0
# 24138593    895835   159838             1                   0
# 25880002    895835   159838             1                   0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 13645692                 17                     NaN       10749
# 17251990                 17                     NaN       33401
# 17622767                 17                     NaN       23695
# 24138593                 17                     NaN       21334
# 25880002                 17                     NaN       22198
#
#           add_to_cart_order  reordered  \
# 13645692                  3          0
# 17251990                  6          0
# 17622767                  2          0
# 24138593                  5          0
# 25880002                  1          0
#
#                                                product_name  ...  _merge  \
# 13645692                            Organic Red Bell Pepper  ...    both
# 17251990                               Goat Cheese Crumbles  ...    both
# 17622767                           California Veggie Burger  ...    both
# 24138593                              Organic Peeled Garlic  ...    both
# 25880002  4X Ultra Concentrated Natural Laundry Detergen...  ...    both
#
#           busiest_day  busiest_days busiest_period_of_day max_order  \
# 13645692  Busiest day  Busiest days        Average orders         1
# 17251990  Busiest day  Busiest days        Average orders         1
# 17622767  Busiest day  Busiest days        Average orders         1
# 24138593  Busiest day  Busiest days        Average orders         1
# 25880002  Busiest day  Busiest days        Average orders         1
#
#           loyalty_flag mean_spend  spender_flag median_order_frequency  \
# 13645692  New customer       7.42   Low spender                    NaN
# 17251990  New customer       7.42   Low spender                    NaN
# 17622767  New customer       7.42   Low spender                    NaN
# 24138593  New customer       7.42   Low spender                    NaN
# 25880002  New customer       7.42   Low spender                    NaN
#
#           order_frequency_flag
# 13645692                   NaN
# 17251990                   NaN
# 17622767                   NaN
# 24138593                   NaN
# 25880002                   NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# All null values are customers who only ordered 1 time. All they have for a median is "null". Will replace values in flag column, but leave value in median column

# %% [markdown]
# Note: If "null" in median_order_frequency column -> order_number = 1, "Non-frequent customer"

# %%
# Replacing null values in flag column with "Non-Frequent customer"
ords_prods_merge['order_frequency_flag'].fillna('Non-frequent customer', inplace = True)

# %%
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636442
# Name: count, dtype: int64

# %% [markdown]
# Non-frequent customer count increased by 5, counts check out.

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merged_updated_2.pkl'))
